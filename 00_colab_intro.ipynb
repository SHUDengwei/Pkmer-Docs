# %% [markdown]
# <a href="https://colab.research.google.com/github/SHUDengwei/Pkmer-Docs/blob/main/00_colab_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DevFest 2025｜AI学习助手工作坊
#
# ## 模块0：Gemini + Colab 快速上手
#
# 目标：让你在 10 分钟内完成环境配置，成功调用 Gemini。

# %% [markdown]
# ### 1) 什么是 Gemini？
# - Google 最新多模态大模型，会读文本/图片/代码，能生成内容、讲解知识、写程序。
#
# ### 2) 什么是 Colab？
# - 云端版 Jupyter Notebook，无需安装 Python，打开浏览器即可运行代码。

# %%
print('你好，欢迎来到 DevFest 2025｜AI学习助手工作坊！')
# Out:
# 你好，欢迎来到 DevFest 2025｜AI学习助手工作坊！

# %% [markdown]
# ### 3) 安装依赖
# - 本工作坊使用 `google-generativeai` 官方 SDK。

# %%
# !pip -q install google-generativeai pandas numpy

# %% [markdown]
# ### 4) 配置 API Key
# 在 Colab 运行本单元后，**用你的真实密钥替换占位文本**。注意：此方式仅在当前会话生效。

# %%
import os
from google.colab import userdata

# 设置 Gemini API Key
os.environ['GEMINI_API_KEY'] = userdata.get('GEMINI_API_KEY')
assert os.getenv('GEMINI_API_KEY'), '请先粘贴你的 Gemini API Key 再继续运行'
print('✅ 已设置 GEMINI_API_KEY')
# Out:
# ✅ 已设置 GEMINI_API_KEY

# %% [markdown]
# ### 5) 测试调用 Gemini

# %%
import google.generativeai as genai, os
genai.configure(api_key=os.getenv('GEMINI_API_KEY'))
model = genai.GenerativeModel('gemini-2.5-pro')
resp = model.generate_content('请用一句话鼓励学习者，坚持每天学习30分钟。')
print(resp.text)
# Out:
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# /tmp/ipython-input-1776625454.py in <cell line: 0>()
#       2 genai.configure(api_key=os.getenv('GEMINI_API_KEY'))
#       3 model = genai.GenerativeModel('gemini-2.5-pro')
# ----> 4 resp = model.generate_content('请用一句话鼓励学习者，坚持每天学习30分钟。')
#       5 print(resp.text)
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# ...

# %% [markdown]
# > 如果上面输出了一句鼓励话语，说明环境配置成功！🎉
